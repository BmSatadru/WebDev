# %%
# !pwd
# Out:
# /content

# %%
! pip install pyngrok

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# changing the working directory
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/FlaskDemo-Colab")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/FlaskDemo-Colab

# %%
# checking present working directory
! pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/FlaskDemo-Colab

# %%
# Configuring Flask with ngrok
from flask import Flask, render_template
from pyngrok import ngrok
app = Flask(__name__)
ngrok.set_auth_token("2geHWvy3lvHeFWp9qRK9qyvywIR_dD5mFGTKL2GtofFrDRAw")
pub_url=ngrok.connect(5000).public_url
print(pub_url)

#===============================================#
@app.route("/")
def home():
  return render_template("index.html")
app.run(port = 5000)
# Out:
# https://160e-34-75-5-37.ngrok-free.app
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [19/May/2024 09:04:54] "GET / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [19/May/2024 09:04:55] "GET /favicon.ico HTTP/1.1" 404 -
